# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
from albumentations import *
from skimage.transform import resize

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score

from keras.layers import *
from keras.callbacks import *
from keras.optimizers import *
from keras.models import load_model, Model

import tensorflow as tf
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
SHAPE = (224, 224, 3)
BATCH_SIZE = 24
EPOCHS = 100
N_SPLITS = 5
SEED = 1881
TRAIN_TEST_RATIO = 0.2

BASE_DIR     = "../../data/BreaKHis_v1/histology_slides/breast/"
DATASET_MODE = "40X"

# %%
class BREAKHIST_DATASET:
    
    """
    input_shape           --> TUPLE.wanted image size
    batch_size            --> INT.yielding data size for every iteration
    orders                --> LIST.which images will be used. max=len(all_images). it can be used for K-fold(CV).
    base_dir              --> STR.the DIR which is include "benign" and "malignant" dirs.
    dataset_mode          --> STR. Which type of images will be used: "40X", "100X", "200X", "400X".
    seed                  --> INT. This allow to dataset generator to more reproduciable and it ensures that x and y are shuffled with compatible.
    augment               --> BOOL. Augment data or not.
    train_test_ratio      --> How much of data will be used as test set.
    ---------
    GENERAL_CLASSES       --> LIST.["benign", "malignant"]
    BENIGN_SUB_CLASSES    --> LIST.["adenosis", "fibroadenoma", "phyllodes_tumor", "tubular_adenoma"]
    MALIGNANT_SUB_CLASSES --> LIST.["ductal_carcinoma", "lobular_carcinoma", "mucinous_carcinoma", "papillary_carcinoma"]
    """
    
    def __init__(self, input_shape, batch_size, orders, base_dir, dataset_mode, seed, train_test_ratio, augment=True):
        self.SHAPE                 = input_shape
        self.BATCH_SIZE            = batch_size
        self.arr                   = orders
        self.DATASET_MODE          = dataset_mode
        self.SEED                  = seed
        self.TT_RATIO              = train_test_ratio
        self.AUG                   = augment
        
        self.BASE_DIR              = base_dir
        self.GENERAL_CLASSES       = ["benign", "malignant"]
        self.BENIGN_SUB_CLASSES    = ["adenosis", "fibroadenoma", "phyllodes_tumor", "tubular_adenoma"]
        self.MALIGNANT_SUB_CLASSES = ["ductal_carcinoma", "lobular_carcinoma", "mucinous_carcinoma", "papillary_carcinoma"]
        
        
    def get_paths_n_labels(self):

        x      = []
        label = []

        for ix1, a in enumerate(self.GENERAL_CLASSES):
            if ix1 == 0:
                for ix2, b in enumerate(self.BENIGN_SUB_CLASSES):
                    path1 = self.BASE_DIR+a+"/SOB/"+b
                    for c in os.listdir(path1):
                        path2 = path1+"/"+c+"/"+self.DATASET_MODE
                        for img_name in os.listdir(path2):
                            path3 = path2+"/"+img_name

                            # x
                            img_path = path3 #np.array(Image.open(path3), dtype=np.float16)

                            # y
                            main_targets = np.zeros((2), dtype=np.float32) # BENIGN OR MALIGNANT
                            main_targets[ix1] = 1.

                            # Store the values
                            x.append(img_path)
                            label.append(main_targets)

                            
            if ix1 == 1:
                for ix2, b in enumerate(self.MALIGNANT_SUB_CLASSES):
                    path1 = self.BASE_DIR+a+"/SOB/"+b
                    for c in os.listdir(path1):
                        path2 = path1+"/"+c+"/"+self.DATASET_MODE
                        for img_name in os.listdir(path2):
                            path3 = path2+"/"+img_name

                            # x
                            img_path = path3  #np.array(Image.open(path3), dtype=np.float16)

                            # y
                            main_targets = np.zeros((2), dtype=np.float32) # BENIGN OR MALIGNANT
                            main_targets[ix1] = 1.
                     
                            # Store the values
                            x.append(img_path)
                            label.append(main_targets)
                           
        return x, label
    
    def __len__(self):
        return len(self.get_paths_n_labels()[0])
    
    def get_img(self, img_path):
        img = Image.open(img_path)
        return np.array(img)
    
    def augmenting(self, img):
        if self.AUG:
            augment = Compose([VerticalFlip(p=0.5),
                               HorizontalFlip(p=0.5),
                               RandomBrightnessContrast(p=0.3),
                               ShiftScaleRotate(p=0.5, shift_limit=0.2, scale_limit=0.2, rotate_limit=20)])  
        else:
            augment = Compose([])  

        img = augment(image=img)['image']
        return img
    
    
    def resize_and_normalize(self, img):
        img = resize(img, self.SHAPE)
        return img
    
    def get_shuffled_data(self):
        img_paths, labels = self.get_paths_n_labels()

        np.random.seed(self.SEED) 
        np.random.shuffle(img_paths)
        
        np.random.seed(self.SEED) 
        np.random.shuffle(labels)
        
        return img_paths, labels
        
    def split_train_test(self, get):  # get=={"train","test"}
        img_paths, labels = self.get_shuffled_data()
        x_train, x_test, y_train, y_test = train_test_split(img_paths, labels, test_size=self.TT_RATIO, random_state=self.SEED)
        
        if get=='train':
            return x_train, y_train
        
        elif get=='test':
            return x_test, y_test
    
    def data_generator(self):
        img_paths, labels = self.split_train_test(get="train")
        
        while True:
            x = np.empty((self.BATCH_SIZE,)+self.SHAPE, dtype=np.float32)
            y = np.empty((self.BATCH_SIZE, 2), dtype=np.float32)

            batch = np.random.choice(self.arr, self.BATCH_SIZE)

            for ix, id_ in enumerate(batch):
                # x
                img_path = img_paths[id_]
                img = self.get_img(img_path)
                img = self.augmenting(img)
                img = self.resize_and_normalize(img)
                  
                # y 
                label = labels[id_]
             
                # Store the values    
                x[ix] = img
                y[ix] = label

            yield x, y

# %%
dataset = BREAKHIST_DATASET(SHAPE, 1, range(4), BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=True)

for ix, data in enumerate(dataset.data_generator()):
    img, y = data
    print(img)
    print(img.shape)
    print("-"*10)
    print(y)
    print(y.shape)
    print("-"*10)
    print(img[0,:,:,:].shape)
    plt.imshow(img[0,:,:,:])
    plt.show()
    
    if ix==0:
        break
# Out:
# [[[[0.86092436 0.8803681  0.8236454 ]
#    [0.86106664 0.8730414  0.8179294 ]
#    [0.8557423  0.87578565 0.81510633]
#    ...
#    [0.8438025  0.74522275 0.782377  ]
#    [0.75026697 0.67792803 0.7652858 ]
#    [0.6877254  0.58811057 0.72584474]]
#
#   [[0.84705883 0.8742647  0.8117647 ]
#    [0.8595588  0.8752451  0.81827074]
#    [0.85811234 0.8737986  0.8188966 ]
#    ...
#    [0.8077403  0.7077731  0.7587579 ]
#    [0.67564774 0.57853425 0.69580925]
#    [0.8222689  0.7205532  0.8433189 ]]
#
#   [[0.84457284 0.8719341  0.8132003 ]
#    [0.85843617 0.8761423  0.8193387 ]
#    [0.85882354 0.8745098  0.81960785]
#    ...
#    [0.71309745 0.6104495  0.69293594]
#    [0.80129987 0.6920343  0.8112067 ]
#    [0.9383141  0.844691   0.95552564]]
#
#   ...
#
#   [[0.8813463  0.8806066  0.84779847]
#    [0.8634804  0.86930364 0.8382813 ]
#    [0.8572763  0.86511946 0.8267507 ]
#    ...
#    [0.9018448  0.8773831  0.90962446]
#    [0.76538646 0.7378173  0.80632   ]
#    [0.78673625 0.7628961  0.8125175 ]]
#
#   [[0.87387955 0.8780462  0.83504903]
#    [0.8648175  0.87027967 0.8010854 ]
#    [0.86034226 0.86107534 0.8091058 ]
#    ...
#    [0.85726976 0.8463454  0.8936734 ]
#    [0.68945205 0.6735973  0.6888502 ]
#    [0.75549066 0.7529653  0.75906426]]
#
#   [[0.8671219  0.874965   0.8314535 ]
#    [0.8809458  0.8766763  0.8041995 ]
#    [0.8721595  0.8639312  0.8177718 ]
#    ...
#    [0.73669904 0.74483764 0.78709954]
#    [0.74738705 0.7707086  0.7712338 ]
#    [0.7601278  0.7924435  0.7923626 ]]]]
# (1, 224, 224, 3)
# ----------
# [[1. 0.]]
# (1, 2)
# ----------
# (224, 224, 3)

# %%
# credits: https://stackoverflow.com/questions/43547402/how-to-calculate-f1-macro-in-keras
def recall(y_true, y_pred):
    """
    Recall metric.
    
    Only computes a batch-wise average of recall.
    
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    """Precision metric.
    
    Only computes a batch-wise average of precision.
    
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1(y_true, y_pred):
    precisionx = precision(y_true, y_pred)
    recallx = recall(y_true, y_pred)
    return 2*((precisionx*recallx)/(precisionx+recallx+K.epsilon()))

# %%
class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
# copied from https://github.com/kobiso/CBAM-keras/blob/master/models/attention_module.py
def cbam_block(cbam_feature, ratio=8):
    """Contains the implementation of Convolutional Block Attention Module(CBAM) block.
    As described in https://arxiv.org/abs/1807.06521.
    """
    
    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature._keras_shape[channel_axis]
    
    shared_layer_one = Dense(channel//ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    shared_layer_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    
    avg_pool = GlobalAveragePooling2D()(input_feature)    
    avg_pool = Reshape((1,1,channel))(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel)
    avg_pool = shared_layer_one(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel//ratio)
    avg_pool = shared_layer_two(avg_pool)
    assert avg_pool._keras_shape[1:] == (1,1,channel)
    
    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel)
    max_pool = shared_layer_one(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel//ratio)
    max_pool = shared_layer_two(max_pool)
    assert max_pool._keras_shape[1:] == (1,1,channel)
    
    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
    
    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7
    
    if K.image_data_format() == "channels_first":
        channel = input_feature._keras_shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature._keras_shape[-1]
        cbam_feature = input_feature
    
    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    assert avg_pool._keras_shape[-1] == 1
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    assert max_pool._keras_shape[-1] == 1
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    assert concat._keras_shape[-1] == 2
    cbam_feature = Conv2D(filters = 1,
                    kernel_size=kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)(concat)	
    assert cbam_feature._keras_shape[-1] == 1
    
    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
        
    return multiply([input_feature, cbam_feature])

# %%
# copied from https://gist.github.com/mjdietzx/5319e42637ed7ef095d430cb5c5e8c64
def residual_block(y, nb_channels, _strides=(1, 1), _project_shortcut=False):
    shortcut = y

    # down-sampling is performed with a stride of 2
    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
    y = BatchNormalization()(y)
    y = LeakyReLU()(y)

    y = Conv2D(nb_channels, kernel_size=(3, 3), strides=(1, 1), padding='same')(y)
    y = BatchNormalization()(y)

    # identity shortcuts used directly when the input and output are of the same dimensions
    if _project_shortcut or _strides != (1, 1):
        # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
        # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
        shortcut = Conv2D(nb_channels, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    y = add([shortcut, y])
    y = LeakyReLU()(y)

    return y

# %%
def create_model():
    
    dropRate = 0.3
    
    init = Input(SHAPE)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(init) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), activation=None, padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x1 = MaxPooling2D((2,2))(x)
    
    x = Conv2D(64, (3, 3), activation=None, padding='same')(x1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)
    x = residual_block(x, 64)
    x2 = MaxPooling2D((2,2))(x)
    
    x = Conv2D(128, (3, 3), activation=None, padding='same')(x2)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = cbam_block(x)
    x = residual_block(x, 128)
    x3 = MaxPooling2D((2,2))(x)
    
    ginp1 = UpSampling2D(size=(2, 2), interpolation='bilinear')(x1)
    ginp2 = UpSampling2D(size=(4, 4), interpolation='bilinear')(x2)
    ginp3 = UpSampling2D(size=(8, 8), interpolation='bilinear')(x3)
    
    hypercolumn = Concatenate()([ginp1, ginp2, ginp3]) 
    gap = GlobalAveragePooling2D()(hypercolumn)

    x = Dense(256, activation=None)(gap)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropRate)(x)
    
    x = Dense(256, activation=None)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    y = Dense(2, activation='softmax')(x)
   
    model = Model(init, y)
    return model

# %%
model = create_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           activation_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 64)           0           activation_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 64)     0           global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 8)      520         reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 64)     576         dense_1[0][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 1, 64)     0           dense_2[0][0]
#                                                                  dense_2[1][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 112, 112, 64) 0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 112, 112, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 112, 112, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112, 112, 2)  0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 1)  98          concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 112, 112, 64) 0           multiply_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 64) 36928       multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 64) 36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 64) 0           multiply_2[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 112, 112, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 128)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 128)    0           global_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 16)     2064        reshape_3[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 128)    2176        dense_3[0][0]
#                                                                  dense_3[1][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 1, 128)    0           dense_4[0][0]
#                                                                  dense_4[1][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 56, 56, 128)  0           activation_5[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 2)    0           lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 1)    98          concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 56, 56, 128)  0           multiply_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  147584      multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  147584      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 128)  0           multiply_4[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 56, 56, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 224, 224, 32) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 64) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 128 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 224 0           up_sampling2d_1[0][0]
#                                                                  up_sampling2d_2[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 224)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          57600       global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256)          1024        dense_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          65792       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256)          1024        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            514         activation_8[0][0]
# ==================================================================================================
# Total params: 605,566
# Trainable params: 603,262
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
kf = KFold(n_splits=N_SPLITS, random_state=SEED, shuffle=True)

for ix, (train_index, test_index) in enumerate(kf.split(range(len(dataset.split_train_test("train")[0])))):
                                               
    tg = BREAKHIST_DATASET(SHAPE, BATCH_SIZE, train_index, BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=True)
    vg = BREAKHIST_DATASET(SHAPE, BATCH_SIZE, test_index , BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=False)
        
    schedule = SGDRScheduler(min_lr=1e-6,
                             max_lr=1e-3,
                             steps_per_epoch=np.ceil(EPOCHS/BATCH_SIZE),
                             lr_decay=0.9,
                             cycle_length=10,
                             mult_factor=2.)

    model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=1e-3), metrics=[precision, recall, f1, 'acc'])

    model_ckpt = "BREAKHIST_FOLD_"+str(ix)+".h5"
    callbacks = [ModelCheckpoint(model_ckpt, monitor='val_loss', mode='min', verbose=1, save_best_only=True, save_weights_only=False),
                 TensorBoard(log_dir='./log_'+str(ix), update_freq='batch'), 
                 schedule] 
                                               
    model.fit_generator(tg.data_generator(),
                        steps_per_epoch=len(train_index)//BATCH_SIZE,
                        epochs=EPOCHS,
                        verbose=2,
                        validation_data=vg.data_generator(),
                        validation_steps=len(test_index)//BATCH_SIZE,
                        callbacks=callbacks)
# Out:
# Epoch 1/100
#  - 79s - loss: 0.5477 - precision: 0.7335 - recall: 0.7335 - f1: 0.7335 - acc: 0.7335 - val_loss: 0.3880 - val_precision: 0.8077 - val_recall: 0.8077 - val_f1: 0.8077 - val_acc: 0.8077
#
# Epoch 00001: val_loss improved from inf to 0.38805, saving model to BREAKHIST_FOLD_0.h5
# Epoch 2/100
#  - 47s - loss: 0.4859 - precision: 0.7799 - recall: 0.7799 - f1: 0.7799 - acc: 0.7799 - val_loss: 3.6210 - val_precision: 0.2724 - val_recall: 0.2724 - val_f1: 0.2724 - val_acc: 0.2724
#
# Epoch 00002: val_loss did not improve from 0.38805
# Epoch 3/100
#  - 57s - loss: 0.4850 - precision: 0.7830 - recall: 0.7830 - f1: 0.7830 - acc: 0.7830 - val_loss: 0.6729 - val_precision: 0.6763 - val_recall: 0.6763 - val_f1: 0.6763 - val_acc: 0.6763
#
# Epoch 00003: val_loss did not improve from 0.38805
# Epoch 4/100
#  - 45s - loss: 0.4827 - precision: 0.7869 - recall: 0.7869 - f1: 0.7869 - acc: 0.7869 - val_loss: 1.0960 - val_precision: 0.6186 - val_recall: 0.6186 - val_f1: 0.6186 - val_acc: 0.6186
#
# Epoch 00004: val_loss did not improve from 0.38805
# Epoch 5/100
#  - 39s - loss: 0.4097 - precision: 0.8153 - recall: 0.8153 - f1: 0.8153 - acc: 0.8153 - val_loss: 0.4623 - val_precision: 0.8397 - val_recall: 0.8397 - val_f1: 0.8397 - val_acc: 0.8397
#
# Epoch 00005: val_loss did not improve from 0.38805
# Epoch 6/100
#  - 38s - loss: 0.4383 - precision: 0.8097 - recall: 0.8097 - f1: 0.8097 - acc: 0.8097 - val_loss: 2.2093 - val_precision: 0.3429 - val_recall: 0.3429 - val_f1: 0.3429 - val_acc: 0.3429
#
# Epoch 00006: val_loss did not improve from 0.38805
# Epoch 7/100
#  - 38s - loss: 0.4069 - precision: 0.8168 - recall: 0.8168 - f1: 0.8168 - acc: 0.8168 - val_loss: 0.3718 - val_precision: 0.8173 - val_recall: 0.8173 - val_f1: 0.8173 - val_acc: 0.8173
#
# Epoch 00007: val_loss improved from 0.38805 to 0.37183, saving model to BREAKHIST_FOLD_0.h5
# Epoch 8/100
#  - 38s - loss: 0.3778 - precision: 0.8388 - recall: 0.8388 - f1: 0.8388 - acc: 0.8388 - val_loss: 2.0572 - val_precision: 0.3333 - val_recall: 0.3333 - val_f1: 0.3333 - val_acc: 0.3333
#
# Epoch 00008: val_loss did not improve from 0.37183
# Epoch 9/100
#  - 37s - loss: 0.3763 - precision: 0.8530 - recall: 0.8530 - f1: 0.8530 - acc: 0.8530 - val_loss: 1.4042 - val_precision: 0.3590 - val_recall: 0.3590 - val_f1: 0.3590 - val_acc: 0.3590
#
# Epoch 00009: val_loss did not improve from 0.37183
# Epoch 10/100
#  - 38s - loss: 0.3308 - precision: 0.8742 - recall: 0.8742 - f1: 0.8742 - acc: 0.8742 - val_loss: 1.4428 - val_precision: 0.5224 - val_recall: 0.5224 - val_f1: 0.5224 - val_acc: 0.5224
#
# Epoch 00010: val_loss did not improve from 0.37183
# Epoch 11/100
#  - 37s - loss: 0.3715 - precision: 0.8404 - recall: 0.8404 - f1: 0.8404 - acc: 0.8404 - val_loss: 1.9692 - val_precision: 0.7404 - val_recall: 0.7404 - val_f1: 0.7404 - val_acc: 0.7404
#
# Epoch 00011: val_loss did not improve from 0.37183
# Epoch 12/100
#  - 37s - loss: 0.2854 - precision: 0.8868 - recall: 0.8868 - f1: 0.8868 - acc: 0.8868 - val_loss: 0.4691 - val_precision: 0.8622 - val_recall: 0.8622 - val_f1: 0.8622 - val_acc: 0.8622
#
# Epoch 00012: val_loss did not improve from 0.37183
# Epoch 13/100
#  - 37s - loss: 0.2965 - precision: 0.8781 - recall: 0.8781 - f1: 0.8781 - acc: 0.8781 - val_loss: 0.8466 - val_precision: 0.7660 - val_recall: 0.7660 - val_f1: 0.7660 - val_acc: 0.7660
#
# Epoch 00013: val_loss did not improve from 0.37183
# Epoch 14/100
#  - 38s - loss: 0.3172 - precision: 0.8726 - recall: 0.8726 - f1: 0.8726 - acc: 0.8726 - val_loss: 0.3043 - val_precision: 0.9038 - val_recall: 0.9038 - val_f1: 0.9038 - val_acc: 0.9038
#
# Epoch 00014: val_loss improved from 0.37183 to 0.30430, saving model to BREAKHIST_FOLD_0.h5
# Epoch 15/100
#  - 35s - loss: 0.2991 - precision: 0.8687 - recall: 0.8687 - f1: 0.8687 - acc: 0.8687 - val_loss: 0.2933 - val_precision: 0.8974 - val_recall: 0.8974 - val_f1: 0.8974 - val_acc: 0.8974
#
# Epoch 00015: val_loss improved from 0.30430 to 0.29334, saving model to BREAKHIST_FOLD_0.h5
# Epoch 16/100
#  - 35s - loss: 0.2745 - precision: 0.8876 - recall: 0.8876 - f1: 0.8876 - acc: 0.8876 - val_loss: 0.1778 - val_precision: 0.9103 - val_recall: 0.9103 - val_f1: 0.9103 - val_acc: 0.9103
#
# Epoch 00016: val_loss improved from 0.29334 to 0.17781, saving model to BREAKHIST_FOLD_0.h5
# Epoch 17/100
#  - 35s - loss: 0.2634 - precision: 0.8805 - recall: 0.8805 - f1: 0.8805 - acc: 0.8805 - val_loss: 0.3951 - val_precision: 0.8558 - val_recall: 0.8558 - val_f1: 0.8558 - val_acc: 0.8558
#
# Epoch 00017: val_loss did not improve from 0.17781
# Epoch 18/100
#  - 35s - loss: 0.2782 - precision: 0.8899 - recall: 0.8899 - f1: 0.8899 - acc: 0.8899 - val_loss: 1.8084 - val_precision: 0.4904 - val_recall: 0.4904 - val_f1: 0.4904 - val_acc: 0.4904
#
# Epoch 00018: val_loss did not improve from 0.17781
# Epoch 19/100
#  - 35s - loss: 0.2694 - precision: 0.8947 - recall: 0.8947 - f1: 0.8947 - acc: 0.8947 - val_loss: 0.2177 - val_precision: 0.9071 - val_recall: 0.9071 - val_f1: 0.9071 - val_acc: 0.9071
#
# Epoch 00019: val_loss did not improve from 0.17781
# Epoch 20/100
#  - 35s - loss: 0.2470 - precision: 0.9057 - recall: 0.9057 - f1: 0.9057 - acc: 0.9057 - val_loss: 0.1472 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00020: val_loss improved from 0.17781 to 0.14716, saving model to BREAKHIST_FOLD_0.h5
# Epoch 21/100
#  - 35s - loss: 0.2749 - precision: 0.8978 - recall: 0.8978 - f1: 0.8978 - acc: 0.8978 - val_loss: 0.2758 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00021: val_loss did not improve from 0.14716
# Epoch 22/100
#  - 35s - loss: 0.2900 - precision: 0.8774 - recall: 0.8774 - f1: 0.8774 - acc: 0.8774 - val_loss: 0.5308 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00022: val_loss did not improve from 0.14716
# Epoch 23/100
#  - 35s - loss: 0.2593 - precision: 0.8947 - recall: 0.8947 - f1: 0.8947 - acc: 0.8947 - val_loss: 0.2358 - val_precision: 0.8974 - val_recall: 0.8974 - val_f1: 0.8974 - val_acc: 0.8974
#
# Epoch 00023: val_loss did not improve from 0.14716
# Epoch 24/100
#  - 35s - loss: 0.2299 - precision: 0.9159 - recall: 0.9159 - f1: 0.9159 - acc: 0.9159 - val_loss: 0.1620 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00024: val_loss did not improve from 0.14716
# Epoch 25/100
#  - 35s - loss: 0.2681 - precision: 0.8892 - recall: 0.8892 - f1: 0.8892 - acc: 0.8892 - val_loss: 0.5109 - val_precision: 0.7853 - val_recall: 0.7853 - val_f1: 0.7853 - val_acc: 0.7853
#
# Epoch 00025: val_loss did not improve from 0.14716
# Epoch 26/100
#  - 35s - loss: 0.2545 - precision: 0.8907 - recall: 0.8907 - f1: 0.8907 - acc: 0.8907 - val_loss: 1.4309 - val_precision: 0.5128 - val_recall: 0.5128 - val_f1: 0.5128 - val_acc: 0.5128
#
# Epoch 00026: val_loss did not improve from 0.14716
# Epoch 27/100
#  - 35s - loss: 0.2230 - precision: 0.9143 - recall: 0.9143 - f1: 0.9143 - acc: 0.9143 - val_loss: 0.2051 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00027: val_loss did not improve from 0.14716
# Epoch 28/100
#  - 35s - loss: 0.1925 - precision: 0.9285 - recall: 0.9285 - f1: 0.9285 - acc: 0.9285 - val_loss: 0.1906 - val_precision: 0.9135 - val_recall: 0.9135 - val_f1: 0.9135 - val_acc: 0.9135
#
# Epoch 00028: val_loss did not improve from 0.14716
# Epoch 29/100
#  - 35s - loss: 0.2317 - precision: 0.8986 - recall: 0.8986 - f1: 0.8986 - acc: 0.8986 - val_loss: 0.2482 - val_precision: 0.9006 - val_recall: 0.9006 - val_f1: 0.9006 - val_acc: 0.9006
#
# Epoch 00029: val_loss did not improve from 0.14716
# Epoch 30/100
#  - 35s - loss: 0.2068 - precision: 0.9261 - recall: 0.9261 - f1: 0.9261 - acc: 0.9261 - val_loss: 0.2464 - val_precision: 0.9071 - val_recall: 0.9071 - val_f1: 0.9071 - val_acc: 0.9071
#
# Epoch 00030: val_loss did not improve from 0.14716
# Epoch 31/100
#  - 35s - loss: 0.3020 - precision: 0.8852 - recall: 0.8852 - f1: 0.8852 - acc: 0.8852 - val_loss: 3.0860 - val_precision: 0.3622 - val_recall: 0.3622 - val_f1: 0.3622 - val_acc: 0.3622
#
# Epoch 00031: val_loss did not improve from 0.14716
# Epoch 32/100
#  - 35s - loss: 0.1821 - precision: 0.9237 - recall: 0.9237 - f1: 0.9237 - acc: 0.9237 - val_loss: 0.3492 - val_precision: 0.8397 - val_recall: 0.8397 - val_f1: 0.8397 - val_acc: 0.8397
#
# Epoch 00032: val_loss did not improve from 0.14716
# Epoch 33/100
#  - 35s - loss: 0.2198 - precision: 0.9119 - recall: 0.9119 - f1: 0.9119 - acc: 0.9119 - val_loss: 0.2283 - val_precision: 0.9231 - val_recall: 0.9231 - val_f1: 0.9231 - val_acc: 0.9231
#
# Epoch 00033: val_loss did not improve from 0.14716
# Epoch 34/100
#  - 36s - loss: 0.1764 - precision: 0.9269 - recall: 0.9269 - f1: 0.9269 - acc: 0.9269 - val_loss: 0.1047 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00034: val_loss improved from 0.14716 to 0.10471, saving model to BREAKHIST_FOLD_0.h5
# Epoch 35/100
#  - 35s - loss: 0.1740 - precision: 0.9347 - recall: 0.9347 - f1: 0.9347 - acc: 0.9347 - val_loss: 0.1251 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00035: val_loss did not improve from 0.10471
# Epoch 36/100
#  - 35s - loss: 0.1701 - precision: 0.9355 - recall: 0.9355 - f1: 0.9355 - acc: 0.9355 - val_loss: 0.2549 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00036: val_loss did not improve from 0.10471
# Epoch 37/100
#  - 36s - loss: 0.2148 - precision: 0.9135 - recall: 0.9135 - f1: 0.9135 - acc: 0.9135 - val_loss: 0.3909 - val_precision: 0.7853 - val_recall: 0.7853 - val_f1: 0.7853 - val_acc: 0.7853
#
# Epoch 00037: val_loss did not improve from 0.10471
# Epoch 38/100
#  - 35s - loss: 0.2090 - precision: 0.9159 - recall: 0.9159 - f1: 0.9159 - acc: 0.9159 - val_loss: 0.4802 - val_precision: 0.7853 - val_recall: 0.7853 - val_f1: 0.7853 - val_acc: 0.7853
#
# Epoch 00038: val_loss did not improve from 0.10471
# Epoch 39/100
#  - 35s - loss: 0.2045 - precision: 0.9159 - recall: 0.9159 - f1: 0.9159 - acc: 0.9159 - val_loss: 0.3505 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00039: val_loss did not improve from 0.10471
# Epoch 40/100
#  - 35s - loss: 0.1775 - precision: 0.9316 - recall: 0.9316 - f1: 0.9316 - acc: 0.9316 - val_loss: 0.4086 - val_precision: 0.8846 - val_recall: 0.8846 - val_f1: 0.8846 - val_acc: 0.8846
#
# Epoch 00040: val_loss did not improve from 0.10471
# Epoch 41/100
#  - 35s - loss: 0.1540 - precision: 0.9450 - recall: 0.9450 - f1: 0.9450 - acc: 0.9450 - val_loss: 0.2408 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00041: val_loss did not improve from 0.10471
# Epoch 42/100
#  - 35s - loss: 0.1374 - precision: 0.9497 - recall: 0.9497 - f1: 0.9497 - acc: 0.9497 - val_loss: 0.1625 - val_precision: 0.9423 - val_recall: 0.9423 - val_f1: 0.9423 - val_acc: 0.9423
#
# Epoch 00042: val_loss did not improve from 0.10471
# Epoch 43/100
#  - 36s - loss: 0.1446 - precision: 0.9450 - recall: 0.9450 - f1: 0.9450 - acc: 0.9450 - val_loss: 0.1466 - val_precision: 0.9487 - val_recall: 0.9487 - val_f1: 0.9487 - val_acc: 0.9487
#
# Epoch 00043: val_loss did not improve from 0.10471
# Epoch 44/100
#  - 35s - loss: 0.1662 - precision: 0.9332 - recall: 0.9332 - f1: 0.9332 - acc: 0.9332 - val_loss: 2.3332 - val_precision: 0.3718 - val_recall: 0.3718 - val_f1: 0.3718 - val_acc: 0.3718
#
# Epoch 00044: val_loss did not improve from 0.10471
# Epoch 45/100
#  - 36s - loss: 0.2100 - precision: 0.9198 - recall: 0.9198 - f1: 0.9198 - acc: 0.9198 - val_loss: 0.5279 - val_precision: 0.8494 - val_recall: 0.8494 - val_f1: 0.8494 - val_acc: 0.8494
#
# Epoch 00045: val_loss did not improve from 0.10471
# Epoch 46/100
#  - 36s - loss: 0.2265 - precision: 0.9135 - recall: 0.9135 - f1: 0.9135 - acc: 0.9135 - val_loss: 0.3122 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00046: val_loss did not improve from 0.10471
# Epoch 47/100
#  - 35s - loss: 0.1847 - precision: 0.9269 - recall: 0.9269 - f1: 0.9269 - acc: 0.9269 - val_loss: 0.8695 - val_precision: 0.6058 - val_recall: 0.6058 - val_f1: 0.6058 - val_acc: 0.6058
#
# Epoch 00047: val_loss did not improve from 0.10471
# Epoch 48/100
#  - 36s - loss: 0.1645 - precision: 0.9371 - recall: 0.9371 - f1: 0.9371 - acc: 0.9371 - val_loss: 0.1354 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00048: val_loss did not improve from 0.10471
# Epoch 49/100
#  - 35s - loss: 0.1647 - precision: 0.9332 - recall: 0.9332 - f1: 0.9332 - acc: 0.9332 - val_loss: 0.1188 - val_precision: 0.9455 - val_recall: 0.9455 - val_f1: 0.9455 - val_acc: 0.9455
#
# Epoch 00049: val_loss did not improve from 0.10471
# Epoch 50/100
#  - 35s - loss: 0.1517 - precision: 0.9403 - recall: 0.9403 - f1: 0.9403 - acc: 0.9403 - val_loss: 0.0526 - val_precision: 0.9840 - val_recall: 0.9840 - val_f1: 0.9840 - val_acc: 0.9840
#
# Epoch 00050: val_loss improved from 0.10471 to 0.05261, saving model to BREAKHIST_FOLD_0.h5
# Epoch 51/100
#  - 36s - loss: 0.1398 - precision: 0.9458 - recall: 0.9458 - f1: 0.9458 - acc: 0.9458 - val_loss: 0.2923 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00051: val_loss did not improve from 0.05261
# Epoch 52/100
#  - 35s - loss: 0.1359 - precision: 0.9418 - recall: 0.9418 - f1: 0.9418 - acc: 0.9418 - val_loss: 0.1565 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00052: val_loss did not improve from 0.05261
# Epoch 53/100
#  - 35s - loss: 0.1883 - precision: 0.9175 - recall: 0.9175 - f1: 0.9175 - acc: 0.9175 - val_loss: 0.4516 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00053: val_loss did not improve from 0.05261
# Epoch 54/100
#  - 35s - loss: 0.2083 - precision: 0.9206 - recall: 0.9206 - f1: 0.9206 - acc: 0.9206 - val_loss: 0.4918 - val_precision: 0.7692 - val_recall: 0.7692 - val_f1: 0.7692 - val_acc: 0.7692
#
# Epoch 00054: val_loss did not improve from 0.05261
# Epoch 55/100
#  - 35s - loss: 0.1632 - precision: 0.9363 - recall: 0.9363 - f1: 0.9363 - acc: 0.9363 - val_loss: 0.2833 - val_precision: 0.8782 - val_recall: 0.8782 - val_f1: 0.8782 - val_acc: 0.8782
#
# Epoch 00055: val_loss did not improve from 0.05261
# Epoch 56/100
#  - 36s - loss: 0.1660 - precision: 0.9347 - recall: 0.9347 - f1: 0.9347 - acc: 0.9347 - val_loss: 0.1193 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00056: val_loss did not improve from 0.05261
# Epoch 57/100
#  - 35s - loss: 0.1436 - precision: 0.9465 - recall: 0.9465 - f1: 0.9465 - acc: 0.9465 - val_loss: 0.0477 - val_precision: 0.9840 - val_recall: 0.9840 - val_f1: 0.9840 - val_acc: 0.9840
#
# Epoch 00057: val_loss improved from 0.05261 to 0.04774, saving model to BREAKHIST_FOLD_0.h5
# Epoch 58/100
#  - 35s - loss: 0.1129 - precision: 0.9599 - recall: 0.9599 - f1: 0.9599 - acc: 0.9599 - val_loss: 0.5168 - val_precision: 0.8269 - val_recall: 0.8269 - val_f1: 0.8269 - val_acc: 0.8269
#
# Epoch 00058: val_loss did not improve from 0.04774
# Epoch 59/100
#  - 36s - loss: 0.1585 - precision: 0.9379 - recall: 0.9379 - f1: 0.9379 - acc: 0.9379 - val_loss: 2.5813 - val_precision: 0.4295 - val_recall: 0.4295 - val_f1: 0.4295 - val_acc: 0.4295
#
# Epoch 00059: val_loss did not improve from 0.04774
# Epoch 60/100
#  - 36s - loss: 0.1751 - precision: 0.9269 - recall: 0.9269 - f1: 0.9269 - acc: 0.9269 - val_loss: 0.1814 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00060: val_loss did not improve from 0.04774
# Epoch 61/100
#  - 35s - loss: 0.1824 - precision: 0.9300 - recall: 0.9300 - f1: 0.9300 - acc: 0.9300 - val_loss: 0.5236 - val_precision: 0.7981 - val_recall: 0.7981 - val_f1: 0.7981 - val_acc: 0.7981
#
# Epoch 00061: val_loss did not improve from 0.04774
# Epoch 62/100
#  - 35s - loss: 0.1704 - precision: 0.9324 - recall: 0.9324 - f1: 0.9324 - acc: 0.9324 - val_loss: 0.4530 - val_precision: 0.8718 - val_recall: 0.8718 - val_f1: 0.8718 - val_acc: 0.8718
#
# Epoch 00062: val_loss did not improve from 0.04774
# Epoch 63/100
#  - 35s - loss: 0.1356 - precision: 0.9465 - recall: 0.9465 - f1: 0.9465 - acc: 0.9465 - val_loss: 0.2028 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00063: val_loss did not improve from 0.04774
# Epoch 64/100
#  - 35s - loss: 0.1289 - precision: 0.9505 - recall: 0.9505 - f1: 0.9505 - acc: 0.9505 - val_loss: 0.1296 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00064: val_loss did not improve from 0.04774
# Epoch 65/100
#  - 36s - loss: 0.1047 - precision: 0.9638 - recall: 0.9638 - f1: 0.9638 - acc: 0.9638 - val_loss: 0.0807 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
# Epoch 00065: val_loss did not improve from 0.04774
# Epoch 66/100
#  - 35s - loss: 0.1130 - precision: 0.9575 - recall: 0.9575 - f1: 0.9575 - acc: 0.9575 - val_loss: 0.5093 - val_precision: 0.8301 - val_recall: 0.8301 - val_f1: 0.8301 - val_acc: 0.8301
#
# Epoch 00066: val_loss did not improve from 0.04774
# Epoch 67/100
#  - 35s - loss: 0.1386 - precision: 0.9473 - recall: 0.9473 - f1: 0.9473 - acc: 0.9473 - val_loss: 0.6595 - val_precision: 0.8173 - val_recall: 0.8173 - val_f1: 0.8173 - val_acc: 0.8173
#
# Epoch 00067: val_loss did not improve from 0.04774
# Epoch 68/100
#  - 35s - loss: 0.1841 - precision: 0.9340 - recall: 0.9340 - f1: 0.9340 - acc: 0.9340 - val_loss: 0.2272 - val_precision: 0.9423 - val_recall: 0.9423 - val_f1: 0.9423 - val_acc: 0.9423
#
# Epoch 00068: val_loss did not improve from 0.04774
# Epoch 69/100
#  - 36s - loss: 0.1987 - precision: 0.9206 - recall: 0.9206 - f1: 0.9206 - acc: 0.9206 - val_loss: 0.5124 - val_precision: 0.8397 - val_recall: 0.8397 - val_f1: 0.8397 - val_acc: 0.8397
#
# Epoch 00069: val_loss did not improve from 0.04774
# Epoch 70/100
#  - 35s - loss: 0.1180 - precision: 0.9568 - recall: 0.9568 - f1: 0.9568 - acc: 0.9568 - val_loss: 0.1720 - val_precision: 0.9199 - val_recall: 0.9199 - val_f1: 0.9199 - val_acc: 0.9199
#
# Epoch 00070: val_loss did not improve from 0.04774
# Epoch 71/100
#  - 35s - loss: 0.1153 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.1795 - val_precision: 0.9391 - val_recall: 0.9391 - val_f1: 0.9391 - val_acc: 0.9391
#
# Epoch 00071: val_loss did not improve from 0.04774
# Epoch 72/100
#  - 35s - loss: 0.1341 - precision: 0.9528 - recall: 0.9528 - f1: 0.9528 - acc: 0.9528 - val_loss: 0.2993 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00072: val_loss did not improve from 0.04774
# Epoch 73/100
#  - 35s - loss: 0.1644 - precision: 0.9418 - recall: 0.9418 - f1: 0.9418 - acc: 0.9418 - val_loss: 0.5233 - val_precision: 0.7212 - val_recall: 0.7212 - val_f1: 0.7212 - val_acc: 0.7212
#
# Epoch 00073: val_loss did not improve from 0.04774
# Epoch 74/100
#  - 35s - loss: 0.1348 - precision: 0.9473 - recall: 0.9473 - f1: 0.9473 - acc: 0.9473 - val_loss: 0.0983 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00074: val_loss did not improve from 0.04774
# Epoch 75/100
#  - 35s - loss: 0.1043 - precision: 0.9591 - recall: 0.9591 - f1: 0.9591 - acc: 0.9591 - val_loss: 0.0940 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
#
# Epoch 00075: val_loss did not improve from 0.04774
# Epoch 76/100
#  - 35s - loss: 0.0965 - precision: 0.9662 - recall: 0.9662 - f1: 0.9662 - acc: 0.9662 - val_loss: 0.0658 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00076: val_loss did not improve from 0.04774
# Epoch 77/100
#  - 35s - loss: 0.0925 - precision: 0.9654 - recall: 0.9654 - f1: 0.9654 - acc: 0.9654 - val_loss: 0.0925 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00077: val_loss did not improve from 0.04774
# Epoch 78/100
#  - 35s - loss: 0.0877 - precision: 0.9701 - recall: 0.9701 - f1: 0.9701 - acc: 0.9701 - val_loss: 0.0684 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00078: val_loss did not improve from 0.04774
# Epoch 79/100
#  - 36s - loss: 0.0869 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.0703 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
#
# Epoch 00079: val_loss did not improve from 0.04774
# Epoch 80/100
#  - 35s - loss: 0.0938 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.1129 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00080: val_loss did not improve from 0.04774
# Epoch 81/100
#  - 35s - loss: 0.0962 - precision: 0.9638 - recall: 0.9638 - f1: 0.9638 - acc: 0.9638 - val_loss: 0.0930 - val_precision: 0.9679 - val_recall: 0.9679 - val_f1: 0.9679 - val_acc: 0.9679
#
# Epoch 00081: val_loss did not improve from 0.04774
# Epoch 82/100
#  - 35s - loss: 0.1181 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.2332 - val_precision: 0.9295 - val_recall: 0.9295 - val_f1: 0.9295 - val_acc: 0.9295
#
# Epoch 00082: val_loss did not improve from 0.04774
# Epoch 83/100
#  - 35s - loss: 0.1101 - precision: 0.9599 - recall: 0.9599 - f1: 0.9599 - acc: 0.9599 - val_loss: 0.2741 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00083: val_loss did not improve from 0.04774
# Epoch 84/100
#  - 35s - loss: 0.1285 - precision: 0.9544 - recall: 0.9544 - f1: 0.9544 - acc: 0.9544 - val_loss: 0.1424 - val_precision: 0.9487 - val_recall: 0.9487 - val_f1: 0.9487 - val_acc: 0.9487
#
# Epoch 00084: val_loss did not improve from 0.04774
# Epoch 85/100
#  - 36s - loss: 0.1288 - precision: 0.9465 - recall: 0.9465 - f1: 0.9465 - acc: 0.9465 - val_loss: 0.1726 - val_precision: 0.9199 - val_recall: 0.9199 - val_f1: 0.9199 - val_acc: 0.9199
#
# Epoch 00085: val_loss did not improve from 0.04774
# Epoch 86/100
#  - 36s - loss: 0.1315 - precision: 0.9497 - recall: 0.9497 - f1: 0.9497 - acc: 0.9497 - val_loss: 0.1828 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00086: val_loss did not improve from 0.04774
# Epoch 87/100
#  - 35s - loss: 0.1044 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.1818 - val_precision: 0.9231 - val_recall: 0.9231 - val_f1: 0.9231 - val_acc: 0.9231
#
# Epoch 00087: val_loss did not improve from 0.04774
# Epoch 88/100
#  - 36s - loss: 0.0994 - precision: 0.9670 - recall: 0.9670 - f1: 0.9670 - acc: 0.9670 - val_loss: 0.3444 - val_precision: 0.9071 - val_recall: 0.9071 - val_f1: 0.9071 - val_acc: 0.9071
#
# Epoch 00088: val_loss did not improve from 0.04774
# Epoch 89/100
#  - 35s - loss: 0.1060 - precision: 0.9623 - recall: 0.9623 - f1: 0.9623 - acc: 0.9623 - val_loss: 0.1340 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00089: val_loss did not improve from 0.04774
# Epoch 90/100
#  - 35s - loss: 0.1188 - precision: 0.9497 - recall: 0.9497 - f1: 0.9497 - acc: 0.9497 - val_loss: 0.1653 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00090: val_loss did not improve from 0.04774
# Epoch 91/100
#  - 35s - loss: 0.0868 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.1322 - val_precision: 0.9615 - val_recall: 0.9615 - val_f1: 0.9615 - val_acc: 0.9615
#
# Epoch 00091: val_loss did not improve from 0.04774
# Epoch 92/100
#  - 36s - loss: 0.0695 - precision: 0.9764 - recall: 0.9764 - f1: 0.9764 - acc: 0.9764 - val_loss: 0.0913 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00092: val_loss did not improve from 0.04774
# Epoch 93/100
#  - 35s - loss: 0.0699 - precision: 0.9741 - recall: 0.9741 - f1: 0.9741 - acc: 0.9741 - val_loss: 0.0815 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00093: val_loss did not improve from 0.04774
# Epoch 94/100
#  - 35s - loss: 0.0978 - precision: 0.9568 - recall: 0.9568 - f1: 0.9568 - acc: 0.9568 - val_loss: 0.0501 - val_precision: 0.9808 - val_recall: 0.9808 - val_f1: 0.9808 - val_acc: 0.9808
#
# Epoch 00094: val_loss did not improve from 0.04774
# Epoch 95/100
#  - 35s - loss: 0.1043 - precision: 0.9631 - recall: 0.9631 - f1: 0.9631 - acc: 0.9631 - val_loss: 0.0577 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00095: val_loss did not improve from 0.04774
# Epoch 96/100
#  - 35s - loss: 0.0847 - precision: 0.9654 - recall: 0.9654 - f1: 0.9654 - acc: 0.9654 - val_loss: 0.3572 - val_precision: 0.9006 - val_recall: 0.9006 - val_f1: 0.9006 - val_acc: 0.9006
#
# Epoch 00096: val_loss did not improve from 0.04774
# Epoch 97/100
#  - 35s - loss: 0.0970 - precision: 0.9607 - recall: 0.9607 - f1: 0.9607 - acc: 0.9607 - val_loss: 0.1223 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00097: val_loss did not improve from 0.04774
# Epoch 98/100
#  - 35s - loss: 0.1049 - precision: 0.9599 - recall: 0.9599 - f1: 0.9599 - acc: 0.9599 - val_loss: 0.3217 - val_precision: 0.9006 - val_recall: 0.9006 - val_f1: 0.9006 - val_acc: 0.9006
# Epoch 00098: val_loss did not improve from 0.04774
# Epoch 99/100
#  - 36s - loss: 0.1413 - precision: 0.9513 - recall: 0.9513 - f1: 0.9513 - acc: 0.9513 - val_loss: 1.4506 - val_precision: 0.6154 - val_recall: 0.6154 - val_f1: 0.6154 - val_acc: 0.6154
#
# Epoch 00099: val_loss did not improve from 0.04774
# Epoch 100/100
#  - 35s - loss: 0.1186 - precision: 0.9536 - recall: 0.9536 - f1: 0.9536 - acc: 0.9536 - val_loss: 0.3406 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1: 0.9167 - val_acc: 0.9167
#
# Epoch 00100: val_loss did not improve from 0.04774
# Epoch 1/100
#  - 37s - loss: 0.1744 - precision: 0.9347 - recall: 0.9347 - f1: 0.9347 - acc: 0.9347 - val_loss: 0.9211 - val_precision: 0.7724 - val_recall: 0.7724 - val_f1: 0.7724 - val_acc: 0.7724
#
# Epoch 00001: val_loss improved from inf to 0.92109, saving model to BREAKHIST_FOLD_1.h5
# Epoch 2/100
#  - 35s - loss: 0.1255 - precision: 0.9520 - recall: 0.9520 - f1: 0.9520 - acc: 0.9520 - val_loss: 0.4958 - val_precision: 0.7276 - val_recall: 0.7276 - val_f1: 0.7276 - val_acc: 0.7276
#
# Epoch 00002: val_loss improved from 0.92109 to 0.49578, saving model to BREAKHIST_FOLD_1.h5
# Epoch 3/100
#  - 36s - loss: 0.1230 - precision: 0.9575 - recall: 0.9575 - f1: 0.9575 - acc: 0.9575 - val_loss: 0.4633 - val_precision: 0.8013 - val_recall: 0.8013 - val_f1: 0.8013 - val_acc: 0.8013
#
# Epoch 00003: val_loss improved from 0.49578 to 0.46327, saving model to BREAKHIST_FOLD_1.h5
# Epoch 4/100
#  - 36s - loss: 0.1754 - precision: 0.9363 - recall: 0.9363 - f1: 0.9363 - acc: 0.9363 - val_loss: 0.1698 - val_precision: 0.9423 - val_recall: 0.9423 - val_f1: 0.9423 - val_acc: 0.9423
#
# Epoch 00004: val_loss improved from 0.46327 to 0.16979, saving model to BREAKHIST_FOLD_1.h5
# Epoch 5/100
#  - 36s - loss: 0.1542 - precision: 0.9371 - recall: 0.9371 - f1: 0.9371 - acc: 0.9371 - val_loss: 0.1429 - val_precision: 0.9423 - val_recall: 0.9423 - val_f1: 0.9423 - val_acc: 0.9423
#
# Epoch 00005: val_loss improved from 0.16979 to 0.14285, saving model to BREAKHIST_FOLD_1.h5
# Epoch 6/100
#  - 36s - loss: 0.1546 - precision: 0.9403 - recall: 0.9403 - f1: 0.9403 - acc: 0.9403 - val_loss: 0.5710 - val_precision: 0.7788 - val_recall: 0.7788 - val_f1: 0.7788 - val_acc: 0.7788
#
# Epoch 00006: val_loss did not improve from 0.14285
# Epoch 7/100
#  - 36s - loss: 0.1481 - precision: 0.9520 - recall: 0.9520 - f1: 0.9520 - acc: 0.9520 - val_loss: 0.1773 - val_precision: 0.8878 - val_recall: 0.8878 - val_f1: 0.8878 - val_acc: 0.8878
#
# Epoch 00007: val_loss did not improve from 0.14285
# Epoch 8/100
#  - 36s - loss: 0.1334 - precision: 0.9458 - recall: 0.9458 - f1: 0.9458 - acc: 0.9458 - val_loss: 0.4807 - val_precision: 0.8013 - val_recall: 0.8013 - val_f1: 0.8013 - val_acc: 0.8013
#
# Epoch 00008: val_loss did not improve from 0.14285
# Epoch 9/100
#  - 36s - loss: 0.1175 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.2635 - val_precision: 0.8750 - val_recall: 0.8750 - val_f1: 0.8750 - val_acc: 0.8750
#
# Epoch 00009: val_loss did not improve from 0.14285
# Epoch 10/100
#  - 35s - loss: 0.1573 - precision: 0.9426 - recall: 0.9426 - f1: 0.9426 - acc: 0.9426 - val_loss: 0.5840 - val_precision: 0.8814 - val_recall: 0.8814 - val_f1: 0.8814 - val_acc: 0.8814
#
# Epoch 00010: val_loss did not improve from 0.14285
# Epoch 11/100
#  - 36s - loss: 0.1128 - precision: 0.9591 - recall: 0.9591 - f1: 0.9591 - acc: 0.9591 - val_loss: 0.4612 - val_precision: 0.8686 - val_recall: 0.8686 - val_f1: 0.8686 - val_acc: 0.8686
#
# Epoch 00011: val_loss did not improve from 0.14285
# Epoch 12/100
#  - 36s - loss: 0.1291 - precision: 0.9599 - recall: 0.9599 - f1: 0.9599 - acc: 0.9599 - val_loss: 0.1240 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00012: val_loss improved from 0.14285 to 0.12396, saving model to BREAKHIST_FOLD_1.h5
# Epoch 13/100
#  - 36s - loss: 0.1385 - precision: 0.9442 - recall: 0.9442 - f1: 0.9442 - acc: 0.9442 - val_loss: 0.1091 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00013: val_loss improved from 0.12396 to 0.10909, saving model to BREAKHIST_FOLD_1.h5
# Epoch 14/100
#  - 35s - loss: 0.0958 - precision: 0.9662 - recall: 0.9662 - f1: 0.9662 - acc: 0.9662 - val_loss: 0.4447 - val_precision: 0.8718 - val_recall: 0.8718 - val_f1: 0.8718 - val_acc: 0.8718
#
# Epoch 00014: val_loss did not improve from 0.10909
# Epoch 15/100
#  - 35s - loss: 0.1370 - precision: 0.9536 - recall: 0.9536 - f1: 0.9536 - acc: 0.9536 - val_loss: 0.3669 - val_precision: 0.8365 - val_recall: 0.8365 - val_f1: 0.8365 - val_acc: 0.8365
#
# Epoch 00015: val_loss did not improve from 0.10909
# Epoch 16/100
#  - 35s - loss: 0.1059 - precision: 0.9568 - recall: 0.9568 - f1: 0.9568 - acc: 0.9568 - val_loss: 0.2961 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00016: val_loss did not improve from 0.10909
# Epoch 17/100
#  - 36s - loss: 0.1181 - precision: 0.9607 - recall: 0.9607 - f1: 0.9607 - acc: 0.9607 - val_loss: 0.6151 - val_precision: 0.8077 - val_recall: 0.8077 - val_f1: 0.8077 - val_acc: 0.8077
#
# Epoch 00017: val_loss did not improve from 0.10909
# Epoch 18/100
#  - 36s - loss: 0.1579 - precision: 0.9332 - recall: 0.9332 - f1: 0.9332 - acc: 0.9332 - val_loss: 0.8110 - val_precision: 0.7949 - val_recall: 0.7949 - val_f1: 0.7949 - val_acc: 0.7949
#
# Epoch 00018: val_loss did not improve from 0.10909
# Epoch 19/100
#  - 36s - loss: 0.1312 - precision: 0.9544 - recall: 0.9544 - f1: 0.9544 - acc: 0.9544 - val_loss: 0.0832 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00019: val_loss improved from 0.10909 to 0.08322, saving model to BREAKHIST_FOLD_1.h5
# Epoch 20/100
#  - 35s - loss: 0.1118 - precision: 0.9568 - recall: 0.9568 - f1: 0.9568 - acc: 0.9568 - val_loss: 0.0819 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00020: val_loss improved from 0.08322 to 0.08188, saving model to BREAKHIST_FOLD_1.h5
# Epoch 21/100
#  - 36s - loss: 0.1239 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.3450 - val_precision: 0.8718 - val_recall: 0.8718 - val_f1: 0.8718 - val_acc: 0.8718
#
# Epoch 00021: val_loss did not improve from 0.08188
# Epoch 22/100
#  - 36s - loss: 0.1289 - precision: 0.9544 - recall: 0.9544 - f1: 0.9544 - acc: 0.9544 - val_loss: 0.3654 - val_precision: 0.7981 - val_recall: 0.7981 - val_f1: 0.7981 - val_acc: 0.7981
#
# Epoch 00022: val_loss did not improve from 0.08188
# Epoch 23/100
#  - 36s - loss: 0.1113 - precision: 0.9662 - recall: 0.9662 - f1: 0.9662 - acc: 0.9662 - val_loss: 0.0774 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00023: val_loss improved from 0.08188 to 0.07740, saving model to BREAKHIST_FOLD_1.h5
# Epoch 24/100
#  - 35s - loss: 0.0894 - precision: 0.9670 - recall: 0.9670 - f1: 0.9670 - acc: 0.9670 - val_loss: 0.0694 - val_precision: 0.9615 - val_recall: 0.9615 - val_f1: 0.9615 - val_acc: 0.9615
#
# Epoch 00024: val_loss improved from 0.07740 to 0.06940, saving model to BREAKHIST_FOLD_1.h5
# Epoch 25/100
#  - 35s - loss: 0.1093 - precision: 0.9631 - recall: 0.9631 - f1: 0.9631 - acc: 0.9631 - val_loss: 0.4823 - val_precision: 0.8365 - val_recall: 0.8365 - val_f1: 0.8365 - val_acc: 0.8365
#
# Epoch 00025: val_loss did not improve from 0.06940
# Epoch 26/100
#  - 36s - loss: 0.1216 - precision: 0.9544 - recall: 0.9544 - f1: 0.9544 - acc: 0.9544 - val_loss: 0.1360 - val_precision: 0.9103 - val_recall: 0.9103 - val_f1: 0.9103 - val_acc: 0.9103
#
# Epoch 00026: val_loss did not improve from 0.06940
# Epoch 27/100
#  - 36s - loss: 0.0987 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.0539 - val_precision: 0.9808 - val_recall: 0.9808 - val_f1: 0.9808 - val_acc: 0.9808
#
# Epoch 00027: val_loss improved from 0.06940 to 0.05392, saving model to BREAKHIST_FOLD_1.h5
# Epoch 28/100
#  - 35s - loss: 0.0827 - precision: 0.9678 - recall: 0.9678 - f1: 0.9678 - acc: 0.9678 - val_loss: 0.5482 - val_precision: 0.8462 - val_recall: 0.8462 - val_f1: 0.8462 - val_acc: 0.8462
#
# Epoch 00028: val_loss did not improve from 0.05392
# Epoch 29/100
#  - 36s - loss: 0.1349 - precision: 0.9536 - recall: 0.9536 - f1: 0.9536 - acc: 0.9536 - val_loss: 0.8014 - val_precision: 0.6987 - val_recall: 0.6987 - val_f1: 0.6987 - val_acc: 0.6987
# Epoch 00029: val_loss did not improve from 0.05392
# Epoch 30/100
#  - 36s - loss: 0.1457 - precision: 0.9481 - recall: 0.9481 - f1: 0.9481 - acc: 0.9481 - val_loss: 0.1291 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00030: val_loss did not improve from 0.05392
# Epoch 31/100
#  - 35s - loss: 0.1268 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.8651 - val_precision: 0.7853 - val_recall: 0.7853 - val_f1: 0.7853 - val_acc: 0.7853
#
# Epoch 00031: val_loss did not improve from 0.05392
# Epoch 32/100
#  - 35s - loss: 0.1332 - precision: 0.9520 - recall: 0.9520 - f1: 0.9520 - acc: 0.9520 - val_loss: 0.1553 - val_precision: 0.9327 - val_recall: 0.9327 - val_f1: 0.9327 - val_acc: 0.9327
#
# Epoch 00032: val_loss did not improve from 0.05392
# Epoch 33/100
#  - 36s - loss: 0.1014 - precision: 0.9654 - recall: 0.9654 - f1: 0.9654 - acc: 0.9654 - val_loss: 0.0882 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
#
# Epoch 00033: val_loss did not improve from 0.05392
# Epoch 34/100
#  - 35s - loss: 0.0774 - precision: 0.9709 - recall: 0.9709 - f1: 0.9709 - acc: 0.9709 - val_loss: 0.0778 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00034: val_loss did not improve from 0.05392
# Epoch 35/100
#  - 35s - loss: 0.0702 - precision: 0.9764 - recall: 0.9764 - f1: 0.9764 - acc: 0.9764 - val_loss: 0.0845 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00035: val_loss did not improve from 0.05392
# Epoch 36/100
#  - 35s - loss: 0.0848 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.1928 - val_precision: 0.9199 - val_recall: 0.9199 - val_f1: 0.9199 - val_acc: 0.9199
#
# Epoch 00036: val_loss did not improve from 0.05392
# Epoch 37/100
#  - 36s - loss: 0.0957 - precision: 0.9623 - recall: 0.9623 - f1: 0.9623 - acc: 0.9623 - val_loss: 0.4039 - val_precision: 0.8301 - val_recall: 0.8301 - val_f1: 0.8301 - val_acc: 0.8301
#
# Epoch 00037: val_loss did not improve from 0.05392
# Epoch 38/100
#  - 35s - loss: 0.1181 - precision: 0.9568 - recall: 0.9568 - f1: 0.9568 - acc: 0.9568 - val_loss: 1.7077 - val_precision: 0.5449 - val_recall: 0.5449 - val_f1: 0.5449 - val_acc: 0.5449
#
# Epoch 00038: val_loss did not improve from 0.05392
# Epoch 39/100
#  - 35s - loss: 0.1069 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9583 - val_loss: 0.2494 - val_precision: 0.9231 - val_recall: 0.9231 - val_f1: 0.9231 - val_acc: 0.9231
#
# Epoch 00039: val_loss did not improve from 0.05392
# Epoch 40/100
#  - 35s - loss: 0.1273 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.1059 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00040: val_loss did not improve from 0.05392
# Epoch 41/100
#  - 35s - loss: 0.0845 - precision: 0.9733 - recall: 0.9733 - f1: 0.9733 - acc: 0.9733 - val_loss: 0.0806 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00041: val_loss did not improve from 0.05392
# Epoch 42/100
#  - 35s - loss: 0.0741 - precision: 0.9772 - recall: 0.9772 - f1: 0.9772 - acc: 0.9772 - val_loss: 0.0884 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00042: val_loss did not improve from 0.05392
# Epoch 43/100
#  - 35s - loss: 0.0751 - precision: 0.9717 - recall: 0.9717 - f1: 0.9717 - acc: 0.9717 - val_loss: 0.1575 - val_precision: 0.9231 - val_recall: 0.9231 - val_f1: 0.9231 - val_acc: 0.9231
#
# Epoch 00043: val_loss did not improve from 0.05392
# Epoch 44/100
#  - 35s - loss: 0.0636 - precision: 0.9780 - recall: 0.9780 - f1: 0.9780 - acc: 0.9780 - val_loss: 0.1197 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00044: val_loss did not improve from 0.05392
# Epoch 45/100
#  - 35s - loss: 0.1228 - precision: 0.9560 - recall: 0.9560 - f1: 0.9560 - acc: 0.9560 - val_loss: 0.4375 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00045: val_loss did not improve from 0.05392
# Epoch 46/100
#  - 35s - loss: 0.1336 - precision: 0.9544 - recall: 0.9544 - f1: 0.9544 - acc: 0.9544 - val_loss: 1.3988 - val_precision: 0.7212 - val_recall: 0.7212 - val_f1: 0.7212 - val_acc: 0.7212
#
# Epoch 00046: val_loss did not improve from 0.05392
# Epoch 47/100
#  - 35s - loss: 0.1078 - precision: 0.9583 - recall: 0.9583 - f1: 0.9583 - acc: 0.9583 - val_loss: 0.5250 - val_precision: 0.8590 - val_recall: 0.8590 - val_f1: 0.8590 - val_acc: 0.8590
#
# Epoch 00047: val_loss did not improve from 0.05392
# Epoch 48/100
#  - 35s - loss: 0.0752 - precision: 0.9764 - recall: 0.9764 - f1: 0.9764 - acc: 0.9764 - val_loss: 0.0850 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00048: val_loss did not improve from 0.05392
# Epoch 49/100
#  - 35s - loss: 0.0690 - precision: 0.9756 - recall: 0.9756 - f1: 0.9756 - acc: 0.9756 - val_loss: 0.0557 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00049: val_loss did not improve from 0.05392
# Epoch 50/100
#  - 36s - loss: 0.0583 - precision: 0.9843 - recall: 0.9843 - f1: 0.9843 - acc: 0.9843 - val_loss: 0.0950 - val_precision: 0.9615 - val_recall: 0.9615 - val_f1: 0.9615 - val_acc: 0.9615
#
# Epoch 00050: val_loss did not improve from 0.05392
# Epoch 51/100
#  - 35s - loss: 0.0850 - precision: 0.9748 - recall: 0.9748 - f1: 0.9748 - acc: 0.9748 - val_loss: 0.8825 - val_precision: 0.7308 - val_recall: 0.7308 - val_f1: 0.7308 - val_acc: 0.7308
#
# Epoch 00051: val_loss did not improve from 0.05392
# Epoch 52/100
#  - 35s - loss: 0.0927 - precision: 0.9638 - recall: 0.9638 - f1: 0.9638 - acc: 0.9638 - val_loss: 1.1125 - val_precision: 0.7340 - val_recall: 0.7340 - val_f1: 0.7340 - val_acc: 0.7340
#
# Epoch 00052: val_loss did not improve from 0.05392
# Epoch 53/100
#  - 36s - loss: 0.1196 - precision: 0.9520 - recall: 0.9520 - f1: 0.9520 - acc: 0.9520 - val_loss: 0.2271 - val_precision: 0.9071 - val_recall: 0.9071 - val_f1: 0.9071 - val_acc: 0.9071
#
# Epoch 00053: val_loss did not improve from 0.05392
# Epoch 54/100
#  - 36s - loss: 0.1069 - precision: 0.9631 - recall: 0.9631 - f1: 0.9631 - acc: 0.9631 - val_loss: 0.2811 - val_precision: 0.8942 - val_recall: 0.8942 - val_f1: 0.8942 - val_acc: 0.8942
#
# Epoch 00054: val_loss did not improve from 0.05392
# Epoch 55/100
#  - 36s - loss: 0.0845 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.1645 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00055: val_loss did not improve from 0.05392
# Epoch 56/100
#  - 36s - loss: 0.0880 - precision: 0.9638 - recall: 0.9638 - f1: 0.9638 - acc: 0.9638 - val_loss: 0.1048 - val_precision: 0.9679 - val_recall: 0.9679 - val_f1: 0.9679 - val_acc: 0.9679
#
# Epoch 00056: val_loss did not improve from 0.05392
# Epoch 57/100
#  - 36s - loss: 0.0772 - precision: 0.9725 - recall: 0.9725 - f1: 0.9725 - acc: 0.9725 - val_loss: 0.0824 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00057: val_loss did not improve from 0.05392
# Epoch 58/100
#  - 36s - loss: 0.0564 - precision: 0.9819 - recall: 0.9819 - f1: 0.9819 - acc: 0.9819 - val_loss: 0.1133 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
#
# Epoch 00058: val_loss did not improve from 0.05392
# Epoch 59/100
#  - 36s - loss: 0.0799 - precision: 0.9725 - recall: 0.9725 - f1: 0.9725 - acc: 0.9725 - val_loss: 0.3508 - val_precision: 0.8910 - val_recall: 0.8910 - val_f1: 0.8910 - val_acc: 0.8910
#
# Epoch 00059: val_loss did not improve from 0.05392
# Epoch 60/100
#  - 36s - loss: 0.0835 - precision: 0.9748 - recall: 0.9748 - f1: 0.9748 - acc: 0.9748 - val_loss: 0.1624 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00060: val_loss did not improve from 0.05392
# Epoch 61/100
#  - 36s - loss: 0.1201 - precision: 0.9552 - recall: 0.9552 - f1: 0.9552 - acc: 0.9552 - val_loss: 1.1057 - val_precision: 0.8141 - val_recall: 0.8141 - val_f1: 0.8141 - val_acc: 0.8141
#
# Epoch 00061: val_loss did not improve from 0.05392
# Epoch 62/100
#  - 36s - loss: 0.0875 - precision: 0.9709 - recall: 0.9709 - f1: 0.9709 - acc: 0.9709 - val_loss: 0.1739 - val_precision: 0.9391 - val_recall: 0.9391 - val_f1: 0.9391 - val_acc: 0.9391
# Epoch 00062: val_loss did not improve from 0.05392
# Epoch 63/100
#  - 36s - loss: 0.0847 - precision: 0.9717 - recall: 0.9717 - f1: 0.9717 - acc: 0.9717 - val_loss: 0.0974 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1: 0.9583 - val_acc: 0.9583
#
# Epoch 00063: val_loss did not improve from 0.05392
# Epoch 64/100
#  - 36s - loss: 0.0654 - precision: 0.9780 - recall: 0.9780 - f1: 0.9780 - acc: 0.9780 - val_loss: 0.0675 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00064: val_loss did not improve from 0.05392
# Epoch 65/100
#  - 36s - loss: 0.0573 - precision: 0.9843 - recall: 0.9843 - f1: 0.9843 - acc: 0.9843 - val_loss: 0.0435 - val_precision: 0.9872 - val_recall: 0.9872 - val_f1: 0.9872 - val_acc: 0.9872
#
# Epoch 00065: val_loss improved from 0.05392 to 0.04355, saving model to BREAKHIST_FOLD_1.h5
# Epoch 66/100
#  - 36s - loss: 0.0652 - precision: 0.9756 - recall: 0.9756 - f1: 0.9756 - acc: 0.9756 - val_loss: 0.0545 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00066: val_loss did not improve from 0.04355
# Epoch 67/100
#  - 36s - loss: 0.0773 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.2035 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00067: val_loss did not improve from 0.04355
# Epoch 68/100
#  - 36s - loss: 0.0752 - precision: 0.9662 - recall: 0.9662 - f1: 0.9662 - acc: 0.9662 - val_loss: 0.9633 - val_precision: 0.6827 - val_recall: 0.6827 - val_f1: 0.6827 - val_acc: 0.6827
#
# Epoch 00068: val_loss did not improve from 0.04355
# Epoch 69/100
#  - 36s - loss: 0.1143 - precision: 0.9678 - recall: 0.9678 - f1: 0.9678 - acc: 0.9678 - val_loss: 0.4221 - val_precision: 0.8590 - val_recall: 0.8590 - val_f1: 0.8590 - val_acc: 0.8590
#
# Epoch 00069: val_loss did not improve from 0.04355
# Epoch 70/100
#  - 36s - loss: 0.0853 - precision: 0.9701 - recall: 0.9701 - f1: 0.9701 - acc: 0.9701 - val_loss: 0.1443 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00070: val_loss did not improve from 0.04355
# Epoch 71/100
#  - 35s - loss: 0.0797 - precision: 0.9780 - recall: 0.9780 - f1: 0.9780 - acc: 0.9780 - val_loss: 0.2372 - val_precision: 0.9135 - val_recall: 0.9135 - val_f1: 0.9135 - val_acc: 0.9135
#
# Epoch 00071: val_loss did not improve from 0.04355
# Epoch 72/100
#  - 36s - loss: 0.0742 - precision: 0.9741 - recall: 0.9741 - f1: 0.9741 - acc: 0.9741 - val_loss: 1.0367 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1: 0.7917 - val_acc: 0.7917
#
# Epoch 00072: val_loss did not improve from 0.04355
# Epoch 73/100
#  - 36s - loss: 0.0671 - precision: 0.9748 - recall: 0.9748 - f1: 0.9748 - acc: 0.9748 - val_loss: 0.4627 - val_precision: 0.8109 - val_recall: 0.8109 - val_f1: 0.8109 - val_acc: 0.8109
#
# Epoch 00073: val_loss did not improve from 0.04355
# Epoch 74/100
#  - 36s - loss: 0.0585 - precision: 0.9796 - recall: 0.9796 - f1: 0.9796 - acc: 0.9796 - val_loss: 0.1132 - val_precision: 0.9615 - val_recall: 0.9615 - val_f1: 0.9615 - val_acc: 0.9615
#
# Epoch 00074: val_loss did not improve from 0.04355
# Epoch 75/100
#  - 36s - loss: 0.0638 - precision: 0.9764 - recall: 0.9764 - f1: 0.9764 - acc: 0.9764 - val_loss: 0.4039 - val_precision: 0.8654 - val_recall: 0.8654 - val_f1: 0.8654 - val_acc: 0.8654
#
# Epoch 00075: val_loss did not improve from 0.04355
# Epoch 76/100
#  - 36s - loss: 0.0536 - precision: 0.9819 - recall: 0.9819 - f1: 0.9819 - acc: 0.9819 - val_loss: 0.0626 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00076: val_loss did not improve from 0.04355
# Epoch 77/100
#  - 36s - loss: 0.0941 - precision: 0.9693 - recall: 0.9693 - f1: 0.9693 - acc: 0.9693 - val_loss: 0.0839 - val_precision: 0.9647 - val_recall: 0.9647 - val_f1: 0.9647 - val_acc: 0.9647
#
# Epoch 00077: val_loss did not improve from 0.04355
# Epoch 78/100
#  - 36s - loss: 0.0374 - precision: 0.9874 - recall: 0.9874 - f1: 0.9874 - acc: 0.9874 - val_loss: 0.1477 - val_precision: 0.9455 - val_recall: 0.9455 - val_f1: 0.9455 - val_acc: 0.9455
#
# Epoch 00078: val_loss did not improve from 0.04355
# Epoch 79/100
#  - 36s - loss: 0.0457 - precision: 0.9835 - recall: 0.9835 - f1: 0.9835 - acc: 0.9835 - val_loss: 0.0606 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00079: val_loss did not improve from 0.04355
# Epoch 80/100
#  - 36s - loss: 0.0448 - precision: 0.9851 - recall: 0.9851 - f1: 0.9851 - acc: 0.9851 - val_loss: 0.1027 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00080: val_loss did not improve from 0.04355
# Epoch 81/100
#  - 36s - loss: 0.0744 - precision: 0.9701 - recall: 0.9701 - f1: 0.9701 - acc: 0.9701 - val_loss: 0.1937 - val_precision: 0.9487 - val_recall: 0.9487 - val_f1: 0.9487 - val_acc: 0.9487
#
# Epoch 00081: val_loss did not improve from 0.04355
# Epoch 82/100
#  - 36s - loss: 0.0772 - precision: 0.9772 - recall: 0.9772 - f1: 0.9772 - acc: 0.9772 - val_loss: 0.1651 - val_precision: 0.9359 - val_recall: 0.9359 - val_f1: 0.9359 - val_acc: 0.9359
#
# Epoch 00082: val_loss did not improve from 0.04355
# Epoch 83/100
#  - 35s - loss: 0.0825 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.4485 - val_precision: 0.8590 - val_recall: 0.8590 - val_f1: 0.8590 - val_acc: 0.8590
#
# Epoch 00083: val_loss did not improve from 0.04355
# Epoch 84/100
#  - 35s - loss: 0.1206 - precision: 0.9591 - recall: 0.9591 - f1: 0.9591 - acc: 0.9591 - val_loss: 0.7660 - val_precision: 0.6859 - val_recall: 0.6859 - val_f1: 0.6859 - val_acc: 0.6859
#
# Epoch 00084: val_loss did not improve from 0.04355
# Epoch 85/100
#  - 35s - loss: 0.0823 - precision: 0.9733 - recall: 0.9733 - f1: 0.9733 - acc: 0.9733 - val_loss: 0.0897 - val_precision: 0.9712 - val_recall: 0.9712 - val_f1: 0.9712 - val_acc: 0.9712
#
# Epoch 00085: val_loss did not improve from 0.04355
# Epoch 86/100
#  - 36s - loss: 0.0792 - precision: 0.9709 - recall: 0.9709 - f1: 0.9709 - acc: 0.9709 - val_loss: 1.4201 - val_precision: 0.6859 - val_recall: 0.6859 - val_f1: 0.6859 - val_acc: 0.6859
#
# Epoch 00086: val_loss did not improve from 0.04355
# Epoch 87/100
#  - 36s - loss: 0.0970 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.4051 - val_precision: 0.8365 - val_recall: 0.8365 - val_f1: 0.8365 - val_acc: 0.8365
#
# Epoch 00087: val_loss did not improve from 0.04355
# Epoch 88/100
#  - 36s - loss: 0.0699 - precision: 0.9756 - recall: 0.9756 - f1: 0.9756 - acc: 0.9756 - val_loss: 0.2695 - val_precision: 0.8494 - val_recall: 0.8494 - val_f1: 0.8494 - val_acc: 0.8494
#
# Epoch 00088: val_loss did not improve from 0.04355
# Epoch 89/100
# ...
#
# Epoch 00037: val_loss did not improve from 0.01346
# Epoch 38/100
#  - 36s - loss: 0.0446 - precision: 0.9835 - recall: 0.9835 - f1: 0.9835 - acc: 0.9835 - val_loss: 0.0362 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00038: val_loss did not improve from 0.01346
# Epoch 39/100
#  - 36s - loss: 0.0762 - precision: 0.9693 - recall: 0.9693 - f1: 0.9693 - acc: 0.9693 - val_loss: 0.1281 - val_precision: 0.9295 - val_recall: 0.9295 - val_f1: 0.9295 - val_acc: 0.9295
#
# Epoch 00039: val_loss did not improve from 0.01346
# Epoch 40/100
#  - 36s - loss: 0.0500 - precision: 0.9858 - recall: 0.9858 - f1: 0.9858 - acc: 0.9858 - val_loss: 0.0411 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00040: val_loss did not improve from 0.01346
# Epoch 41/100
#  - 36s - loss: 0.0440 - precision: 0.9874 - recall: 0.9874 - f1: 0.9874 - acc: 0.9874 - val_loss: 0.0068 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00041: val_loss improved from 0.01346 to 0.00682, saving model to BREAKHIST_FOLD_4.h5
# Epoch 42/100
#  - 36s - loss: 0.0262 - precision: 0.9921 - recall: 0.9921 - f1: 0.9921 - acc: 0.9921 - val_loss: 0.0126 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
#
# Epoch 00042: val_loss did not improve from 0.00682
# Epoch 43/100
#  - 36s - loss: 0.0226 - precision: 0.9953 - recall: 0.9953 - f1: 0.9953 - acc: 0.9953 - val_loss: 0.0990 - val_precision: 0.9487 - val_recall: 0.9487 - val_f1: 0.9487 - val_acc: 0.9487
#
# Epoch 00043: val_loss did not improve from 0.00682
# Epoch 44/100
#  - 36s - loss: 0.0411 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.1056 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00044: val_loss did not improve from 0.00682
# Epoch 45/100
#  - 36s - loss: 0.0312 - precision: 0.9898 - recall: 0.9898 - f1: 0.9898 - acc: 0.9898 - val_loss: 0.6915 - val_precision: 0.8526 - val_recall: 0.8526 - val_f1: 0.8526 - val_acc: 0.8526
#
# Epoch 00045: val_loss did not improve from 0.00682
# Epoch 46/100
#  - 35s - loss: 0.1151 - precision: 0.9646 - recall: 0.9646 - f1: 0.9646 - acc: 0.9646 - val_loss: 0.0761 - val_precision: 0.9744 - val_recall: 0.9744 - val_f1: 0.9744 - val_acc: 0.9744
#
# Epoch 00046: val_loss did not improve from 0.00682
# Epoch 47/100
#  - 35s - loss: 0.0529 - precision: 0.9827 - recall: 0.9827 - f1: 0.9827 - acc: 0.9827 - val_loss: 0.1242 - val_precision: 0.9455 - val_recall: 0.9455 - val_f1: 0.9455 - val_acc: 0.9455
#
# Epoch 00047: val_loss did not improve from 0.00682
# Epoch 48/100
#  - 35s - loss: 0.0472 - precision: 0.9843 - recall: 0.9843 - f1: 0.9843 - acc: 0.9843 - val_loss: 0.0253 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
#
# Epoch 00048: val_loss did not improve from 0.00682
# Epoch 49/100
#  - 36s - loss: 0.0311 - precision: 0.9890 - recall: 0.9890 - f1: 0.9890 - acc: 0.9890 - val_loss: 0.0050 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00049: val_loss improved from 0.00682 to 0.00502, saving model to BREAKHIST_FOLD_4.h5
# Epoch 50/100
#  - 36s - loss: 0.0348 - precision: 0.9914 - recall: 0.9914 - f1: 0.9914 - acc: 0.9914 - val_loss: 0.0050 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.00502
# Epoch 51/100
#  - 36s - loss: 0.0354 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.0229 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
#
# Epoch 00051: val_loss did not improve from 0.00502
# Epoch 52/100
#  - 35s - loss: 0.0996 - precision: 0.9686 - recall: 0.9686 - f1: 0.9686 - acc: 0.9686 - val_loss: 0.4103 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1: 0.8333 - val_acc: 0.8333
#
# Epoch 00052: val_loss did not improve from 0.00502
# Epoch 53/100
#  - 36s - loss: 0.0506 - precision: 0.9811 - recall: 0.9811 - f1: 0.9811 - acc: 0.9811 - val_loss: 0.1804 - val_precision: 0.9199 - val_recall: 0.9199 - val_f1: 0.9199 - val_acc: 0.9199
#
# Epoch 00053: val_loss did not improve from 0.00502
# Epoch 54/100
#  - 36s - loss: 0.0351 - precision: 0.9890 - recall: 0.9890 - f1: 0.9890 - acc: 0.9890 - val_loss: 0.0084 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00054: val_loss did not improve from 0.00502
# Epoch 55/100
#  - 36s - loss: 0.0462 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.0338 - val_precision: 0.9872 - val_recall: 0.9872 - val_f1: 0.9872 - val_acc: 0.9872
#
# Epoch 00055: val_loss did not improve from 0.00502
# Epoch 56/100
#  - 36s - loss: 0.0410 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.0109 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00056: val_loss did not improve from 0.00502
# Epoch 57/100
#  - 36s - loss: 0.0409 - precision: 0.9843 - recall: 0.9843 - f1: 0.9843 - acc: 0.9843 - val_loss: 0.0111 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
# Epoch 00057: val_loss did not improve from 0.00502
# Epoch 58/100
#  - 36s - loss: 0.0559 - precision: 0.9819 - recall: 0.9819 - f1: 0.9819 - acc: 0.9819 - val_loss: 0.0119 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00058: val_loss did not improve from 0.00502
# Epoch 59/100
#  - 36s - loss: 0.0347 - precision: 0.9851 - recall: 0.9851 - f1: 0.9851 - acc: 0.9851 - val_loss: 0.1722 - val_precision: 0.9327 - val_recall: 0.9327 - val_f1: 0.9327 - val_acc: 0.9327
#
# Epoch 00059: val_loss did not improve from 0.00502
# Epoch 60/100
#  - 36s - loss: 0.0526 - precision: 0.9874 - recall: 0.9874 - f1: 0.9874 - acc: 0.9874 - val_loss: 2.8511 - val_precision: 0.5032 - val_recall: 0.5032 - val_f1: 0.5032 - val_acc: 0.5032
#
# Epoch 00060: val_loss did not improve from 0.00502
# Epoch 61/100
#  - 36s - loss: 0.0704 - precision: 0.9709 - recall: 0.9709 - f1: 0.9709 - acc: 0.9709 - val_loss: 0.3630 - val_precision: 0.9038 - val_recall: 0.9038 - val_f1: 0.9038 - val_acc: 0.9038
#
# Epoch 00061: val_loss did not improve from 0.00502
# Epoch 62/100
#  - 36s - loss: 0.0267 - precision: 0.9921 - recall: 0.9921 - f1: 0.9921 - acc: 0.9921 - val_loss: 0.1531 - val_precision: 0.9391 - val_recall: 0.9391 - val_f1: 0.9391 - val_acc: 0.9391
#
# Epoch 00062: val_loss did not improve from 0.00502
# Epoch 63/100
#  - 36s - loss: 0.0327 - precision: 0.9906 - recall: 0.9906 - f1: 0.9906 - acc: 0.9906 - val_loss: 0.0446 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00063: val_loss did not improve from 0.00502
# Epoch 64/100
#  - 36s - loss: 0.0290 - precision: 0.9929 - recall: 0.9929 - f1: 0.9929 - acc: 0.9929 - val_loss: 0.0353 - val_precision: 0.9872 - val_recall: 0.9872 - val_f1: 0.9872 - val_acc: 0.9872
#
# Epoch 00064: val_loss did not improve from 0.00502
# Epoch 65/100
#  - 36s - loss: 0.0351 - precision: 0.9858 - recall: 0.9858 - f1: 0.9858 - acc: 0.9858 - val_loss: 0.0062 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00065: val_loss did not improve from 0.00502
# Epoch 66/100
#  - 36s - loss: 0.0328 - precision: 0.9890 - recall: 0.9890 - f1: 0.9890 - acc: 0.9890 - val_loss: 0.0275 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00066: val_loss did not improve from 0.00502
# Epoch 67/100
#  - 35s - loss: 0.0656 - precision: 0.9772 - recall: 0.9772 - f1: 0.9772 - acc: 0.9772 - val_loss: 4.2938 - val_precision: 0.4103 - val_recall: 0.4103 - val_f1: 0.4103 - val_acc: 0.4103
#
# Epoch 00067: val_loss did not improve from 0.00502
# Epoch 68/100
#  - 36s - loss: 0.0459 - precision: 0.9803 - recall: 0.9803 - f1: 0.9803 - acc: 0.9803 - val_loss: 0.2041 - val_precision: 0.9327 - val_recall: 0.9327 - val_f1: 0.9327 - val_acc: 0.9327
#
# Epoch 00068: val_loss did not improve from 0.00502
# Epoch 69/100
#  - 35s - loss: 0.0551 - precision: 0.9835 - recall: 0.9835 - f1: 0.9835 - acc: 0.9835 - val_loss: 0.0818 - val_precision: 0.9679 - val_recall: 0.9679 - val_f1: 0.9679 - val_acc: 0.9679
#
# Epoch 00069: val_loss did not improve from 0.00502
# Epoch 70/100
#  - 36s - loss: 0.0368 - precision: 0.9898 - recall: 0.9898 - f1: 0.9898 - acc: 0.9898 - val_loss: 0.1437 - val_precision: 0.9295 - val_recall: 0.9295 - val_f1: 0.9295 - val_acc: 0.9295
#
# Epoch 00070: val_loss did not improve from 0.00502
# Epoch 71/100
#  - 36s - loss: 0.0664 - precision: 0.9725 - recall: 0.9725 - f1: 0.9725 - acc: 0.9725 - val_loss: 0.2367 - val_precision: 0.8910 - val_recall: 0.8910 - val_f1: 0.8910 - val_acc: 0.8910
#
# Epoch 00071: val_loss did not improve from 0.00502
# Epoch 72/100
#  - 36s - loss: 0.0338 - precision: 0.9914 - recall: 0.9914 - f1: 0.9914 - acc: 0.9914 - val_loss: 0.1583 - val_precision: 0.9519 - val_recall: 0.9519 - val_f1: 0.9519 - val_acc: 0.9519
#
# Epoch 00072: val_loss did not improve from 0.00502
# Epoch 73/100
#  - 36s - loss: 0.0269 - precision: 0.9914 - recall: 0.9914 - f1: 0.9914 - acc: 0.9914 - val_loss: 0.0339 - val_precision: 0.9840 - val_recall: 0.9840 - val_f1: 0.9840 - val_acc: 0.9840
#
# Epoch 00073: val_loss did not improve from 0.00502
# Epoch 74/100
#  - 36s - loss: 0.0392 - precision: 0.9858 - recall: 0.9858 - f1: 0.9858 - acc: 0.9858 - val_loss: 0.0353 - val_precision: 0.9872 - val_recall: 0.9872 - val_f1: 0.9872 - val_acc: 0.9872
#
# Epoch 00074: val_loss did not improve from 0.00502
# Epoch 75/100
#  - 35s - loss: 0.0477 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.9733 - val_precision: 0.7788 - val_recall: 0.7788 - val_f1: 0.7788 - val_acc: 0.7788
#
# Epoch 00075: val_loss did not improve from 0.00502
# Epoch 76/100
#  - 36s - loss: 0.0395 - precision: 0.9866 - recall: 0.9866 - f1: 0.9866 - acc: 0.9866 - val_loss: 0.0302 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00076: val_loss did not improve from 0.00502
# Epoch 77/100
#  - 36s - loss: 0.0240 - precision: 0.9929 - recall: 0.9929 - f1: 0.9929 - acc: 0.9929 - val_loss: 0.0356 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
#
# Epoch 00077: val_loss did not improve from 0.00502
# Epoch 78/100
#  - 36s - loss: 0.0166 - precision: 0.9945 - recall: 0.9945 - f1: 0.9945 - acc: 0.9945 - val_loss: 0.0052 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00078: val_loss did not improve from 0.00502
# Epoch 79/100
#  - 36s - loss: 0.0365 - precision: 0.9898 - recall: 0.9898 - f1: 0.9898 - acc: 0.9898 - val_loss: 0.0157 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00079: val_loss did not improve from 0.00502
# Epoch 80/100
#  - 36s - loss: 0.0238 - precision: 0.9937 - recall: 0.9937 - f1: 0.9937 - acc: 0.9937 - val_loss: 0.0239 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00080: val_loss did not improve from 0.00502
# Epoch 81/100
#  - 36s - loss: 0.0306 - precision: 0.9890 - recall: 0.9890 - f1: 0.9890 - acc: 0.9890 - val_loss: 0.0241 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00081: val_loss did not improve from 0.00502
# Epoch 82/100
#  - 35s - loss: 0.0289 - precision: 0.9898 - recall: 0.9898 - f1: 0.9898 - acc: 0.9898 - val_loss: 0.0868 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00082: val_loss did not improve from 0.00502
# Epoch 83/100
#  - 36s - loss: 0.0326 - precision: 0.9898 - recall: 0.9898 - f1: 0.9898 - acc: 0.9898 - val_loss: 0.1290 - val_precision: 0.9551 - val_recall: 0.9551 - val_f1: 0.9551 - val_acc: 0.9551
#
# Epoch 00083: val_loss did not improve from 0.00502
# Epoch 84/100
#  - 36s - loss: 0.0546 - precision: 0.9788 - recall: 0.9788 - f1: 0.9788 - acc: 0.9788 - val_loss: 0.0244 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00084: val_loss did not improve from 0.00502
# Epoch 85/100
#  - 36s - loss: 0.0523 - precision: 0.9819 - recall: 0.9819 - f1: 0.9819 - acc: 0.9819 - val_loss: 2.7008 - val_precision: 0.5673 - val_recall: 0.5673 - val_f1: 0.5673 - val_acc: 0.5673
#
# Epoch 00085: val_loss did not improve from 0.00502
# Epoch 86/100
#  - 36s - loss: 0.0553 - precision: 0.9772 - recall: 0.9772 - f1: 0.9772 - acc: 0.9772 - val_loss: 0.1247 - val_precision: 0.9455 - val_recall: 0.9455 - val_f1: 0.9455 - val_acc: 0.9455
#
# Epoch 00086: val_loss did not improve from 0.00502
# Epoch 87/100
#  - 36s - loss: 0.0503 - precision: 0.9819 - recall: 0.9819 - f1: 0.9819 - acc: 0.9819 - val_loss: 0.3073 - val_precision: 0.9263 - val_recall: 0.9263 - val_f1: 0.9263 - val_acc: 0.9263
#
# Epoch 00087: val_loss did not improve from 0.00502
# Epoch 88/100
#  - 36s - loss: 0.0805 - precision: 0.9709 - recall: 0.9709 - f1: 0.9709 - acc: 0.9709 - val_loss: 0.0404 - val_precision: 0.9904 - val_recall: 0.9904 - val_f1: 0.9904 - val_acc: 0.9904
#
# Epoch 00088: val_loss did not improve from 0.00502
# Epoch 89/100
#  - 35s - loss: 0.0407 - precision: 0.9858 - recall: 0.9858 - f1: 0.9858 - acc: 0.9858 - val_loss: 0.1194 - val_precision: 0.9423 - val_recall: 0.9423 - val_f1: 0.9423 - val_acc: 0.9423
#
# Epoch 00089: val_loss did not improve from 0.00502
# Epoch 90/100
#  - 36s - loss: 0.0480 - precision: 0.9827 - recall: 0.9827 - f1: 0.9827 - acc: 0.9827 - val_loss: 0.0211 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
# Epoch 00090: val_loss did not improve from 0.00502
# Epoch 91/100
#  - 36s - loss: 0.0312 - precision: 0.9874 - recall: 0.9874 - f1: 0.9874 - acc: 0.9874 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00091: val_loss did not improve from 0.00502
# Epoch 92/100
#  - 36s - loss: 0.0396 - precision: 0.9874 - recall: 0.9874 - f1: 0.9874 - acc: 0.9874 - val_loss: 0.0100 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00092: val_loss did not improve from 0.00502
# Epoch 93/100
#  - 36s - loss: 0.0189 - precision: 0.9961 - recall: 0.9961 - f1: 0.9961 - acc: 0.9961 - val_loss: 0.0112 - val_precision: 0.9936 - val_recall: 0.9936 - val_f1: 0.9936 - val_acc: 0.9936
#
# Epoch 00093: val_loss did not improve from 0.00502
# Epoch 94/100
#  - 35s - loss: 0.0313 - precision: 0.9882 - recall: 0.9882 - f1: 0.9882 - acc: 0.9882 - val_loss: 0.0127 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00094: val_loss did not improve from 0.00502
# Epoch 95/100
#  - 35s - loss: 0.0227 - precision: 0.9945 - recall: 0.9945 - f1: 0.9945 - acc: 0.9945 - val_loss: 0.0080 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1: 1.0000 - val_acc: 1.0000
#
# Epoch 00095: val_loss did not improve from 0.00502
# Epoch 96/100
#  - 36s - loss: 0.0225 - precision: 0.9921 - recall: 0.9921 - f1: 0.9921 - acc: 0.9921 - val_loss: 0.0177 - val_precision: 0.9872 - val_recall: 0.9872 - val_f1: 0.9872 - val_acc: 0.9872
#
# Epoch 00096: val_loss did not improve from 0.00502
# Epoch 97/100
#  - 36s - loss: 0.0302 - precision: 0.9890 - recall: 0.9890 - f1: 0.9890 - acc: 0.9890 - val_loss: 0.0564 - val_precision: 0.9776 - val_recall: 0.9776 - val_f1: 0.9776 - val_acc: 0.9776
#
# Epoch 00097: val_loss did not improve from 0.00502
# Epoch 98/100
#  - 36s - loss: 0.0471 - precision: 0.9788 - recall: 0.9788 - f1: 0.9788 - acc: 0.9788 - val_loss: 0.1838 - val_precision: 0.9231 - val_recall: 0.9231 - val_f1: 0.9231 - val_acc: 0.9231
#
# Epoch 00098: val_loss did not improve from 0.00502
# Epoch 99/100
#  - 36s - loss: 0.0591 - precision: 0.9788 - recall: 0.9788 - f1: 0.9788 - acc: 0.9788 - val_loss: 2.2040 - val_precision: 0.6955 - val_recall: 0.6955 - val_f1: 0.6955 - val_acc: 0.6955
#
# Epoch 00099: val_loss did not improve from 0.00502
# Epoch 100/100
#  - 36s - loss: 0.0404 - precision: 0.9858 - recall: 0.9858 - f1: 0.9858 - acc: 0.9858 - val_loss: 0.0161 - val_precision: 0.9968 - val_recall: 0.9968 - val_f1: 0.9968 - val_acc: 0.9968
#
# Epoch 00100: val_loss did not improve from 0.00502

# %%
def get_test_data():
    gen = BREAKHIST_DATASET(SHAPE, BATCH_SIZE, range(1), BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=False).split_train_test("test")
                       
    x = np.empty((len(gen[0]),)+SHAPE, dtype=np.float32)
    y = np.empty((len(gen[1]), 2), dtype=np.float32)
    
    for ix, path in tqdm(enumerate(gen[0])):
        img = np.array(Image.open(gen[0][ix]))
        img = resize(img, SHAPE)

        label = gen[1][ix]

        x[ix] = img
        y[ix] = label
        
    return x, y

# %%
x, y = get_test_data()
# Out:
# 399it [00:17, 23.02it/s]

# %%
# Threshold predictions with THRESH_VAL
def threshold_arr(array):
    # Get all value from array
    # Compare calue with THRESH_VAL 
    # IF value >= THRESH_VAL. round to 1
    # ELSE. round to 0
    new_arr = []
    for ix, val in enumerate(array):
        loc = np.array(val).argmax(axis=0)
        k = list(np.zeros((len(val)), dtype=np.float32))
        k[loc]=1
        new_arr.append(k)
        
    return np.array(new_arr, dtype=np.float32)

# %%
models = []
for i in range(5):
    model = load_model("BREAKHIST_FOLD_{}.h5".format(i), custom_objects={'f1': f1, 'precision': precision, 'recall': recall})
    print(model.evaluate(x, y, verbose=0))
    models.append(model)
# Out:
# [0.09851691595519096, 0.9674185463659147, 0.9674185463659147, 0.9674185033430133, 0.9674185463659147]
# [0.08233044977138813, 0.9724310776942355, 0.9724310776942355, 0.9724310442319789, 0.9724310776942355]
# [0.05479078155879239, 0.974937343358396, 0.974937343358396, 0.9749373194567841, 0.974937343358396]
# [0.06933665006680596, 0.9799498746867168, 0.9799498746867168, 0.9799498507851049, 0.9799498746867168]
# [0.10550234063451451, 0.9699248121794602, 0.9699248121794602, 0.969924771696105, 0.9699248121794602]

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig("40X - confusion matrix - 4. FOLD.jpg", dpi=150)
    plt.show()

# %%
y_preds = threshold_arr(models[3].predict(x, verbose=0))

results = precision_recall_fscore_support(y, y_preds ,average='macro')
acc = accuracy_score(y, y_preds)

print("Accuracy: {}, F1_Score: {}, Precision: {}, Recall: {}".format(acc, results[2], results[0], results[1]))
print("\n")
print(classification_report(y, y_preds))
print("\n")
cnf_matrix = confusion_matrix(y.argmax(axis=1), y_preds.argmax(axis=1))

plot_confusion_matrix(cm           = cnf_matrix, 
                      normalize    = False,
                      target_names = ['BENIGN', 'MALIGNANT'],
                      title        = "Confusion Matrix")
# Out:
# Accuracy: 0.9799498746867168, F1_Score: 0.9768009768009769, Precision: 0.9768009768009769, Recall: 0.9768009768009769
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       126
#            1       0.99      0.99      0.99       273
#
#    micro avg       0.98      0.98      0.98       399
#    macro avg       0.98      0.98      0.98       399
# weighted avg       0.98      0.98      0.98       399
#  samples avg       0.98      0.98      0.98       399

# %%
import time
for i in range(5): 
    img = np.array(Image.open(BASE_DIR+"benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-009.png"))
    x = resize(img, SHAPE)
    x = x.reshape((1,) + x.shape) 
    start = time.time()
    prediction = models[3].predict(x, batch_size=1)
    finish = time.time()
    print(threshold_arr(prediction))
    print((finish-start)*1000,"ms")
    print("***")
# Out:
# [[1. 0.]]
# 102.12922096252441 ms
# ***
# [[1. 0.]]
# 15.627622604370117 ms
# ***
# [[1. 0.]]
# 1.2509822845458984 ms
# ***
# [[1. 0.]]
# 8.02302360534668 ms
# ***
# [[1. 0.]]
# 0.0 ms
# ***
